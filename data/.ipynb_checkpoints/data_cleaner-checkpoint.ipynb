# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
conn = sqlite3.connect("data.db")
act = pd.read_sql_query("select rowid from actors where valid=1;", conn)
sur = pd.read_sql_query("select * from survey where valid=1;", conn)
actor_ids = act.rowid.values
# actor_ids = np.array(act[['tothitsexp0', 'tothitsexp1', 'tothitsexp2']])
# sur.head()
# print( in act.rowid)
# print(4 in act.rows)
for index, row in sur.iterrows():
    print(row['actor'] in actor_ids)
# Out:
# False
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...
